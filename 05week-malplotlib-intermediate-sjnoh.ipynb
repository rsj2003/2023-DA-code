# %%
import sys
print(sys.version)
sys.path
# Out:
# 3.11.3 (main, Sep 25 2023, 20:45:01) [Clang 18.0.0 (https://github.com/llvm/llvm-project d1e685df45dc5944b43d2547d013
# ['/home/pyodide',
#  '/lib/python311.zip',
#  '/lib/python3.11',
#  '/lib/python3.11/lib-dynload',
#  '',
#  '/lib/python3.11/site-packages']

# %%
import site
site.getsitepackages()
# Out:
# ['/lib/python3.11/site-packages']

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.5.2'

# %%
import numpy as np
np.__version__
# Out:
# '1.25.2'

# %%
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(7, 4))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

x = np.linspace(-2 * np.pi, 2 * np.pi, 200)
plt.plot(x, np.sin(x)*10)
plt.plot(x, x**2)
plt.plot(x,2 * x**2 - 3*x)

plt.grid(True)
plt.title('adsf')
plt.show()

# %%
import random
import matplotlib.pyplot as plt

dice = []

for i in range(5):
    dice.append(random.randint(1, 6))

print(dice)

plt.hist(dice, bins=6)
plt.show()
# Out:
# [1, 2, 5, 2, 3]

# %%
import matplotlib.pyplot as plt
import random

result = []
for i in range(13):
    result.append(random.randint(1, 1000))
    
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [91, 234, 253, 290, 402, 484, 526, 725, 739, 763, 863, 869, 876]

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
print(sorted(result1))
print(sorted(result2))

plt.boxplot(result1)
plt.boxplot(result2)
plt.show()
# Out:
# [30, 82, 87, 169, 188, 260, 269, 275, 331, 335, 417, 444, 495]
# [564, 569, 607, 623, 630, 790, 844, 858, 876, 892, 922, 962, 983]

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
print(sorted(result1))
print(sorted(result2))

plt.boxplot([result1, result2])
plt.show()
# Out:
# [2, 27, 42, 49, 144, 193, 219, 247, 283, 287, 287, 362, 465]
# [505, 582, 587, 619, 661, 667, 870, 889, 892, 971, 972, 982, 987]

# %%
import matplotlib.pyplot as plt
import numpy as np

ax1 = plt.subplot(2, 1, 1)
plt.plot(np.random.randint(1, 10, 10), 'yo-')
plt.title('A table of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(np.arange(10), np.arange(10)*2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.53;0.775x0.35)
# AxesSubplot(0.125,0.11;0.775x0.35)

# %%
import matplotlib.pyplot as plt

flg, axes = plt.subplots(2, 2)

axes[0, 0].plot([1, 2, 3, 4])
axes[0, 0].set_title("SUbplot 1")

axes[0, 1].plot([4, 3, 2, 1])
axes[0, 1].set_title("SUbplot 2")

axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4], bins=5)
axes[1, 0].set_title("SUbplot 3")

axes[1, 1].scatter([1, 2, 3, 4], [4, 3, 2, 1])
axes[1, 1].set_title("SUbplot 4")

plt.tight_layout()
plt.show()

# %%
flg, axes = plt.subplots(2, 2)

np.random.seed(0)

axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))

ax2 = fig.add_subplot(2, 2, 2)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax3 = fig.add_subplot(2, 2, 3)
